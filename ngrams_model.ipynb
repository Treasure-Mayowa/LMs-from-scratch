# %% [markdown]
# # N-Gram Models

# %% [markdown]
# N-gram is a contiguous sequence of n items from a text or speech sample which can be letters, syllables, or words. It is a simple form of langauge modelling that can capture context and statistical patterns.

# %%
# !uv pip install pandas
# !uv pip install datasets
# Out:
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 236ms
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 117ms

# %%
import random
from collections import Counter, defaultdict
import textwrap
import pandas as pd

# %% [markdown]
# ## Load in Naijaweb Dataset [1]

# %%
from datasets import load_dataset

naija_web = load_dataset("saheedniyi/naijaweb")
dataset = naija_web["train"]["text"][:500]
print(f"The dataset consists of {len(dataset)} paragraphs.")
# Out:
# The dataset consists of 500 paragraphs.

# %%
for paragraph in dataset[:10]:
    formatted_paragraph = textwrap.fill(paragraph)
    print(f"{formatted_paragraph}\n")
# Out:
# Governor Samuel Ortom of Benue State By Peter Duru Governor Samuel
# Ortom of Benue state has commended President Muhammadu Buhari for his
# directive to security agents to shoot anyone illegally bearing AK47
# rifle in the country. The Governor who gave the commendation Thursday
# in Makurdi said the President’s order would reduce the level of
# criminality, banditry and militia herders’ attacks on Benue
# communities as well as in other parts of the country. According to
# him, “the order would also make the communities safer for displaced
# farmers to return to their ancestral homes. “I wish to commend Mr.
# President for his recent order against those bearing AK47 rifles. This
# I am sure will reduce the high rate of criminality, banditary and
# militia herdsmen attacks on our farming communities,” the Governor
# said. He noted that President Buhari had done the right thing by
# listening to the calls he and other concerned Nigerians made on the
# need for the Federal Government to act faster and decisively to save
# the country from degenerating to a state of anarchy. “I don’t only
# criticise, I also commend where necessary. And I want to say shame on
# those sycophants who were bashing me for writing to Mr. President
# because he has finally heeded my advice,” he added. Governor Ortom
# said Nigeria belonged to all its citizens and only justice and equity
# anchored on the rule of law could guarantee the unity and stability of
# the country. Comments expressed here do not reflect the opinions of
# Vanguard newspapers or any employee thereof.
#
# NewsHelm.com offers a unique blend of modernity and trustworthiness.
# Its short and catchy name instantly conveys the idea of a news or
# media platform. This domain name is ideal for businesses in the news
# industry, such as broadcasting, publishing, or journalism. With
# NewsHelm.com, you'll establish a strong online presence and build
# trust with your audience. NewsHelm.com's marketability extends beyond
# the digital realm. It can also be used for branding offline materials
# like business cards, brochures, or signage. Additionally, its easy-to-
# remember nature makes it perfect for radio or television ads, ensuring
# that your brand sticks in listeners' or viewers' minds. NewsHelm.com
# can significantly enhance your online visibility and reach. It can
# improve your search engine rankings by attracting more organic
# traffic. When people search for news-related terms, your website will
# be more likely to appear in the results due to its relevant and
# memorable domain name. A domain like NewsHelm.com can contribute to
# the establishment of a strong brand identity. By using a domain name
# that resonates with your industry and audience, you'll create a sense
# of trust and reliability. This can help you build customer loyalty and
# attract new potential customers, ultimately leading to increased sales
# and revenue. Buy NewsHelm.com Now! At DomainMarket.com our goal is to
# make the domain process as painless and transparent as possible for
# you. Once your funds settle and we have verified the transaction
# (typically between 3 to 7 business days), we will be contacting you
# via email with the transfer instructions to take control of
# NewsHelm.com. To acquire the domain, you incur a one-time expense.
# Subsequently, upon the domain’s transfer to your ownership, you must
# annually renew it through your domain registrar. These renewal charges
# varies depending to your registrar and remitted directly to the
# “Thou shalt not bear false witness against your neighbour!” Governor
# Oshiomhole’s smear campaign against the government of former President
# Jonathan may be down to personal grudge against some functionaries of
# that administration. His tenancy of the Edo State Government House
# expires in a year. When he vacates office, would the Comrade-Governor
# rather prefer a kind of treatment whereby, instead of examining his
# legacy with a sense of duty and balance, a band of critics would rise
# and drown out every other sound with incessant and mordant attacks on
# his name and person? The way things are going, it seems safe to
# suppose that the profession of faith is rampant among politicians who,
# nonetheless, consider the upholding of their religious tenets as the
# tiniest of concerns. The penchant to heap every imaginable sin in the
# world on Dr. Okonjo-Iweala does not wash. Many Nigerians see this as
# unwarranted persecution. In so far as definitions go, Coordinating
# Minister does not mean Supervisory Minister. Ministers in the Jonathan
# administration did not report to Dr. Okonjo-Iweala. Why, then, is she
# being asked to account for all the Ministries in the last dispensation
# when all others who held down ministerial portfolios are alive and
# available? Anti-corruption fights often fail because people distract
# themselves chasing shadows. Mr. President, you should please prevent
# yourself from falling into this trap. The focus should be on
# priorities. Thank you, Mr. President, and may your administration
# represent a spell of God’s abundant blessings on Nigeria. An educated
# and respectable lady, who claimed some presence around today’s
# corridors of power, averred that you recently said that
# yourpresidential tenure would be a loadstar and a legacy for the rest
# of African leaders to emulate. This moved me greatly, to the point
# that I offered an instant prayer for God to strengthen and direct your
# hand to the objective of meaningful and purposeful leadership. Now,
# Mr. President, you will not inhabit Aso Rock forever, even if you
# served multiple terms. The day will eventually come when you will
# become former President Muhammadu Buhari. How would it feel, if after
# you have done your bit and passed the baton, a rabble rises and
# scripts the lyrics of a scathing swansong for you that is antithetical
# to your presidential pedigree? We pray, Mr. President, that
# commentators will not, in the ultimate, have cause to pronounce
# anathema on your administration. I am one of those persuaded that you
# mean well for Nigeria. For this, I recall again that the central
# platform of your campaign for the presidency is the fight against
# corruption. Is this fight now being prosecuted by the virulent attacks
# on the personality and integrity of Ngozi Okonjo-Iweala, by Oshiomhole
# and company? Oshiomhole has, among many other indiscriminate charges,
# accused Dr. Okonjo-Iweala of spending $2.1 billion from the Excess
# Crude Account (ECA) without authorization! How can it be said that
# there was expenditure without authorization, when the evidence is
# there that authorization is undeniable? How are we sure that the
# attacks on this woman is not down to the fact that she published
# details of the Excess Crude monies paid to the Governors most of whom
# cannot now pay salaries of their civil servants, or show to what
# useful purpose they put the funds they readily collected? Isn’t it
# obvious that there are high costs to pay for shadow chasing – like
# when wild allegations are concentrated on the innocent, while an
# expressway is paved for the escape of those who may have some
# explaining to do? In your inaugural address, you paid tribute to
# President Jonathan for his statesmanship in “graciously accepting
# defeat” at the presidential ballot. With the most profound respect, I
# urge you to keep to that path of rectitude.I put it to you, Mr.
# President, that the fight against corruption, which you are leading,
# can do with one imperative, namely, the putting of an immediate end to
# unwarranted and unsubstantiated accusations that can only divert
# attention from the real culprits of corruption, if any? Mr. Chuks
# Iloegbunam, a commentator on national issues, wrote from Lagos.
# Comments expressed here do not reflect the opinions of Vanguard
# newspapers or any employee thereof.

# %% [markdown]
# ## Building blocks for the n-gram model

# %%
from typing import List, Dict

def space_tokenizer(text: str) -> List[str]:
  """Splits a string into a list of words (tokens)"""
  return text.split()

# %%
space_tokenizer(dataset[0])
# Out:
# ['Governor',
#  'Samuel',
#  'Ortom',
#  'of',
#  'Benue',
#  'State',
#  'By',
#  'Peter',
#  'Duru',
#  'Governor',
#  'Samuel',
#  'Ortom',
#  'of',
#  'Benue',
#  'state',
#  'has',
#  'commended',
#  'President',
#  'Muhammadu',
#  'Buhari',
#  'for',
#  'his',
#  'directive',
#  'to',
#  'security',
#  'agents',
#  'to',
#  'shoot',
#  'anyone',
#  'illegally',
#  'bearing',
#  'AK47',
#  'rifle',
#  'in',
#  'the',
#  'country.',
#  'The',
#  'Governor',
#  'who',
#  'gave',
#  'the',
#  'commendation',
#  'Thursday',
#  'in',
#  'Makurdi',
#  'said',
#  'the',
#  'President’s',
#  'order',
#  'would',
#  'reduce',
#  'the',
#  'level',
#  'of',
#  'criminality,',
#  'banditry',
#  'and',
#  'militia',
#  'herders’',
#  'attacks',
#  'on',
#  'Benue',
#  'communities',
#  'as',
#  'well',
#  'as',
#  'in',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'country.',
#  'According',
#  'to',
#  'him,',
#  '“the',
#  'order',
#  'would',
#  'also',
#  'make',
#  'the',
#  'communities',
#  'safer',
#  'for',
#  'displaced',
#  'farmers',
#  'to',
#  'return',
#  'to',
#  'their',
#  'ancestral',
#  'homes.',
#  '“I',
#  'wish',
#  'to',
#  'commend',
#  'Mr.',
#  'President',
#  'for',
#  'his',
#  'recent',
#  'order',
#  'against',
#  'those',
#  'bearing',
#  'AK47',
#  'rifles.',
#  'This',
#  'I',
#  'am',
#  'sure',
#  'will',
#  'reduce',
#  'the',
#  'high',
#  'rate',
#  'of',
#  'criminality,',
#  'banditary',
#  'and',
#  'militia',
#  'herdsmen',
#  'attacks',
#  'on',
#  'our',
#  'farming',
#  'communities,”',
#  'the',
#  'Governor',
#  'said.',
#  'He',
#  'noted',
#  'that',
#  'President',
#  'Buhari',
#  'had',
#  'done',
#  'the',
#  'right',
#  'thing',
#  'by',
#  'listening',
#  'to',
#  'the',
#  'calls',
#  'he',
#  'and',
#  'other',
#  'concerned',
#  'Nigerians',
#  'made',
#  'on',
#  'the',
#  'need',
#  'for',
#  'the',
#  'Federal',
#  'Government',
#  'to',
#  'act',
#  'faster',
#  'and',
#  'decisively',
#  'to',
#  'save',
#  'the',
#  'country',
#  'from',
#  'degenerating',
#  'to',
#  'a',
#  'state',
#  'of',
#  'anarchy.',
#  '“I',
#  'don’t',
#  'only',
#  'criticise,',
#  'I',
#  'also',
#  'commend',
#  'where',
#  'necessary.',
#  'And',
#  'I',
#  'want',
#  'to',
#  'say',
#  'shame',
#  'on',
#  'those',
#  'sycophants',
#  'who',
#  'were',
#  'bashing',
#  'me',
#  'for',
#  'writing',
#  'to',
#  'Mr.',
#  'President',
#  'because',
#  'he',
#  'has',
#  'finally',
#  'heeded',
#  'my',
#  'advice,”',
#  'he',
#  'added.',
#  'Governor',
#  'Ortom',
#  'said',
#  'Nigeria',
#  'belonged',
#  'to',
#  'all',
#  'its',
#  'citizens',
#  'and',
#  'only',
#  'justice',
#  'and',
#  'equity',
#  'anchored',
#  'on',
#  'the',
#  'rule',
#  'of',
#  'law',
#  'could',
#  'guarantee',
#  'the',
#  'unity',
#  'and',
#  'stability',
#  'of',
#  'the',
#  'country.',
#  'Comments',
#  'expressed',
#  'here',
#  'do',
#  'not',
#  'reflect',
#  'the',
#  'opinions',
#  'of',
#  'Vanguard',
#  'newspapers',
#  'or',
#  'any',
#  'employee',
#  'thereof.']

# %%
def generate_ngrams(text: str, n: int) -> List[tuple]:
  """Generates n-grams from a paragraph"""

  tokens = space_tokenizer(text)

  num_of_tokens = len(tokens)

  ngrams = [tuple(tokens[i:i+n]) for  i in range(0, num_of_tokens - n + 1)]


  return ngrams

# %%
generate_ngrams(dataset[0], 2)
# Out:
# [('Governor', 'Samuel'),
#  ('Samuel', 'Ortom'),
#  ('Ortom', 'of'),
#  ('of', 'Benue'),
#  ('Benue', 'State'),
#  ('State', 'By'),
#  ('By', 'Peter'),
#  ('Peter', 'Duru'),
#  ('Duru', 'Governor'),
#  ('Governor', 'Samuel'),
#  ('Samuel', 'Ortom'),
#  ('Ortom', 'of'),
#  ('of', 'Benue'),
#  ('Benue', 'state'),
#  ('state', 'has'),
#  ('has', 'commended'),
#  ('commended', 'President'),
#  ('President', 'Muhammadu'),
#  ('Muhammadu', 'Buhari'),
#  ('Buhari', 'for'),
#  ('for', 'his'),
#  ('his', 'directive'),
#  ('directive', 'to'),
#  ('to', 'security'),
#  ('security', 'agents'),
#  ('agents', 'to'),
#  ('to', 'shoot'),
#  ('shoot', 'anyone'),
#  ('anyone', 'illegally'),
#  ('illegally', 'bearing'),
#  ('bearing', 'AK47'),
#  ('AK47', 'rifle'),
#  ('rifle', 'in'),
#  ('in', 'the'),
#  ('the', 'country.'),
#  ('country.', 'The'),
#  ('The', 'Governor'),
#  ('Governor', 'who'),
#  ('who', 'gave'),
#  ('gave', 'the'),
#  ('the', 'commendation'),
#  ('commendation', 'Thursday'),
#  ('Thursday', 'in'),
#  ('in', 'Makurdi'),
#  ('Makurdi', 'said'),
#  ('said', 'the'),
#  ('the', 'President’s'),
#  ('President’s', 'order'),
#  ('order', 'would'),
#  ('would', 'reduce'),
#  ('reduce', 'the'),
#  ('the', 'level'),
#  ('level', 'of'),
#  ('of', 'criminality,'),
#  ('criminality,', 'banditry'),
#  ('banditry', 'and'),
#  ('and', 'militia'),
#  ('militia', 'herders’'),
#  ('herders’', 'attacks'),
#  ('attacks', 'on'),
#  ('on', 'Benue'),
#  ('Benue', 'communities'),
#  ('communities', 'as'),
#  ('as', 'well'),
#  ('well', 'as'),
#  ('as', 'in'),
#  ('in', 'other'),
#  ('other', 'parts'),
#  ('parts', 'of'),
#  ('of', 'the'),
#  ('the', 'country.'),
#  ('country.', 'According'),
#  ('According', 'to'),
#  ('to', 'him,'),
#  ('him,', '“the'),
#  ('“the', 'order'),
#  ('order', 'would'),
#  ('would', 'also'),
#  ('also', 'make'),
#  ('make', 'the'),
#  ('the', 'communities'),
#  ('communities', 'safer'),
#  ('safer', 'for'),
#  ('for', 'displaced'),
#  ('displaced', 'farmers'),
#  ('farmers', 'to'),
#  ('to', 'return'),
#  ('return', 'to'),
#  ('to', 'their'),
#  ('their', 'ancestral'),
#  ('ancestral', 'homes.'),
#  ('homes.', '“I'),
#  ('“I', 'wish'),
#  ('wish', 'to'),
#  ('to', 'commend'),
#  ('commend', 'Mr.'),
#  ('Mr.', 'President'),
#  ('President', 'for'),
#  ('for', 'his'),
#  ('his', 'recent'),
#  ('recent', 'order'),
#  ('order', 'against'),
#  ('against', 'those'),
#  ('those', 'bearing'),
#  ('bearing', 'AK47'),
#  ('AK47', 'rifles.'),
#  ('rifles.', 'This'),
#  ('This', 'I'),
#  ('I', 'am'),
#  ('am', 'sure'),
#  ('sure', 'will'),
#  ('will', 'reduce'),
#  ('reduce', 'the'),
#  ('the', 'high'),
#  ('high', 'rate'),
#  ('rate', 'of'),
#  ('of', 'criminality,'),
#  ('criminality,', 'banditary'),
#  ('banditary', 'and'),
#  ('and', 'militia'),
#  ('militia', 'herdsmen'),
#  ('herdsmen', 'attacks'),
#  ('attacks', 'on'),
#  ('on', 'our'),
#  ('our', 'farming'),
#  ('farming', 'communities,”'),
#  ('communities,”', 'the'),
#  ('the', 'Governor'),
#  ('Governor', 'said.'),
#  ('said.', 'He'),
#  ('He', 'noted'),
#  ('noted', 'that'),
#  ('that', 'President'),
#  ('President', 'Buhari'),
#  ('Buhari', 'had'),
#  ('had', 'done'),
#  ('done', 'the'),
#  ('the', 'right'),
#  ('right', 'thing'),
#  ('thing', 'by'),
#  ('by', 'listening'),
#  ('listening', 'to'),
#  ('to', 'the'),
#  ('the', 'calls'),
#  ('calls', 'he'),
#  ('he', 'and'),
#  ('and', 'other'),
#  ('other', 'concerned'),
#  ('concerned', 'Nigerians'),
#  ('Nigerians', 'made'),
#  ('made', 'on'),
#  ('on', 'the'),
#  ('the', 'need'),
#  ('need', 'for'),
#  ('for', 'the'),
#  ('the', 'Federal'),
#  ('Federal', 'Government'),
#  ('Government', 'to'),
#  ('to', 'act'),
#  ('act', 'faster'),
#  ('faster', 'and'),
#  ('and', 'decisively'),
#  ('decisively', 'to'),
#  ('to', 'save'),
#  ('save', 'the'),
#  ('the', 'country'),
#  ('country', 'from'),
#  ('from', 'degenerating'),
#  ('degenerating', 'to'),
#  ('to', 'a'),
#  ('a', 'state'),
#  ('state', 'of'),
#  ('of', 'anarchy.'),
#  ('anarchy.', '“I'),
#  ('“I', 'don’t'),
#  ('don’t', 'only'),
#  ('only', 'criticise,'),
#  ('criticise,', 'I'),
#  ('I', 'also'),
#  ('also', 'commend'),
#  ('commend', 'where'),
#  ('where', 'necessary.'),
#  ('necessary.', 'And'),
#  ('And', 'I'),
#  ('I', 'want'),
#  ('want', 'to'),
#  ('to', 'say'),
#  ('say', 'shame'),
#  ('shame', 'on'),
#  ('on', 'those'),
#  ('those', 'sycophants'),
#  ('sycophants', 'who'),
#  ('who', 'were'),
#  ('were', 'bashing'),
#  ('bashing', 'me'),
#  ('me', 'for'),
#  ('for', 'writing'),
#  ('writing', 'to'),
#  ('to', 'Mr.'),
#  ('Mr.', 'President'),
#  ('President', 'because'),
#  ('because', 'he'),
#  ('he', 'has'),
#  ('has', 'finally'),
#  ('finally', 'heeded'),
#  ('heeded', 'my'),
#  ('my', 'advice,”'),
#  ('advice,”', 'he'),
#  ('he', 'added.'),
#  ('added.', 'Governor'),
#  ('Governor', 'Ortom'),
#  ('Ortom', 'said'),
#  ('said', 'Nigeria'),
#  ('Nigeria', 'belonged'),
#  ('belonged', 'to'),
#  ('to', 'all'),
#  ('all', 'its'),
#  ('its', 'citizens'),
#  ('citizens', 'and'),
#  ('and', 'only'),
#  ('only', 'justice'),
#  ('justice', 'and'),
#  ('and', 'equity'),
#  ('equity', 'anchored'),
#  ('anchored', 'on'),
#  ('on', 'the'),
#  ('the', 'rule'),
#  ('rule', 'of'),
#  ('of', 'law'),
#  ('law', 'could'),
#  ('could', 'guarantee'),
#  ('guarantee', 'the'),
#  ('the', 'unity'),
#  ('unity', 'and'),
#  ('and', 'stability'),
#  ('stability', 'of'),
#  ('of', 'the'),
#  ('the', 'country.'),
#  ('country.', 'Comments'),
#  ('Comments', 'expressed'),
#  ('expressed', 'here'),
#  ('here', 'do'),
#  ('do', 'not'),
#  ('not', 'reflect'),
#  ('reflect', 'the'),
#  ('the', 'opinions'),
#  ('opinions', 'of'),
#  ('of', 'Vanguard'),
#  ('Vanguard', 'newspapers'),
#  ('newspapers', 'or'),
#  ('or', 'any'),
#  ('any', 'employee'),
#  ('employee', 'thereof.')]

# %%
generate_ngrams(dataset[1], 3)
# Out:
# [('NewsHelm.com', 'offers', 'a'),
#  ('offers', 'a', 'unique'),
#  ('a', 'unique', 'blend'),
#  ('unique', 'blend', 'of'),
#  ('blend', 'of', 'modernity'),
#  ('of', 'modernity', 'and'),
#  ('modernity', 'and', 'trustworthiness.'),
#  ('and', 'trustworthiness.', 'Its'),
#  ('trustworthiness.', 'Its', 'short'),
#  ('Its', 'short', 'and'),
#  ('short', 'and', 'catchy'),
#  ('and', 'catchy', 'name'),
#  ('catchy', 'name', 'instantly'),
#  ('name', 'instantly', 'conveys'),
#  ('instantly', 'conveys', 'the'),
#  ('conveys', 'the', 'idea'),
#  ('the', 'idea', 'of'),
#  ('idea', 'of', 'a'),
#  ('of', 'a', 'news'),
#  ('a', 'news', 'or'),
#  ('news', 'or', 'media'),
#  ('or', 'media', 'platform.'),
#  ('media', 'platform.', 'This'),
#  ('platform.', 'This', 'domain'),
#  ('This', 'domain', 'name'),
#  ('domain', 'name', 'is'),
#  ('name', 'is', 'ideal'),
#  ('is', 'ideal', 'for'),
#  ('ideal', 'for', 'businesses'),
#  ('for', 'businesses', 'in'),
#  ('businesses', 'in', 'the'),
#  ('in', 'the', 'news'),
#  ('the', 'news', 'industry,'),
#  ('news', 'industry,', 'such'),
#  ('industry,', 'such', 'as'),
#  ('such', 'as', 'broadcasting,'),
#  ('as', 'broadcasting,', 'publishing,'),
#  ('broadcasting,', 'publishing,', 'or'),
#  ('publishing,', 'or', 'journalism.'),
#  ('or', 'journalism.', 'With'),
#  ('journalism.', 'With', 'NewsHelm.com,'),
#  ('With', 'NewsHelm.com,', "you'll"),
#  ('NewsHelm.com,', "you'll", 'establish'),
#  ("you'll", 'establish', 'a'),
#  ('establish', 'a', 'strong'),
#  ('a', 'strong', 'online'),
#  ('strong', 'online', 'presence'),
#  ('online', 'presence', 'and'),
#  ('presence', 'and', 'build'),
#  ('and', 'build', 'trust'),
#  ('build', 'trust', 'with'),
#  ('trust', 'with', 'your'),
#  ('with', 'your', 'audience.'),
#  ('your', 'audience.', "NewsHelm.com's"),
#  ('audience.', "NewsHelm.com's", 'marketability'),
#  ("NewsHelm.com's", 'marketability', 'extends'),
#  ('marketability', 'extends', 'beyond'),
#  ('extends', 'beyond', 'the'),
#  ('beyond', 'the', 'digital'),
#  ('the', 'digital', 'realm.'),
#  ('digital', 'realm.', 'It'),
#  ('realm.', 'It', 'can'),
#  ('It', 'can', 'also'),
#  ('can', 'also', 'be'),
#  ('also', 'be', 'used'),
#  ('be', 'used', 'for'),
#  ('used', 'for', 'branding'),
#  ('for', 'branding', 'offline'),
#  ('branding', 'offline', 'materials'),
#  ('offline', 'materials', 'like'),
#  ('materials', 'like', 'business'),
#  ('like', 'business', 'cards,'),
#  ('business', 'cards,', 'brochures,'),
#  ('cards,', 'brochures,', 'or'),
#  ('brochures,', 'or', 'signage.'),
#  ('or', 'signage.', 'Additionally,'),
#  ('signage.', 'Additionally,', 'its'),
#  ('Additionally,', 'its', 'easy-to-remember'),
#  ('its', 'easy-to-remember', 'nature'),
#  ('easy-to-remember', 'nature', 'makes'),
#  ('nature', 'makes', 'it'),
#  ('makes', 'it', 'perfect'),
#  ('it', 'perfect', 'for'),
#  ('perfect', 'for', 'radio'),
#  ('for', 'radio', 'or'),
#  ('radio', 'or', 'television'),
#  ('or', 'television', 'ads,'),
#  ('television', 'ads,', 'ensuring'),
#  ('ads,', 'ensuring', 'that'),
#  ('ensuring', 'that', 'your'),
#  ('that', 'your', 'brand'),
#  ('your', 'brand', 'sticks'),
#  ('brand', 'sticks', 'in'),
#  ('sticks', 'in', "listeners'"),
#  ('in', "listeners'", 'or'),
#  ("listeners'", 'or', "viewers'"),
#  ('or', "viewers'", 'minds.'),
#  ("viewers'", 'minds.', 'NewsHelm.com'),
#  ('minds.', 'NewsHelm.com', 'can'),
#  ('NewsHelm.com', 'can', 'significantly'),
#  ('can', 'significantly', 'enhance'),
#  ('significantly', 'enhance', 'your'),
#  ('enhance', 'your', 'online'),
#  ('your', 'online', 'visibility'),
#  ('online', 'visibility', 'and'),
#  ('visibility', 'and', 'reach.'),
#  ('and', 'reach.', 'It'),
#  ('reach.', 'It', 'can'),
#  ('It', 'can', 'improve'),
#  ('can', 'improve', 'your'),
#  ('improve', 'your', 'search'),
#  ('your', 'search', 'engine'),
#  ('search', 'engine', 'rankings'),
#  ('engine', 'rankings', 'by'),
#  ('rankings', 'by', 'attracting'),
#  ('by', 'attracting', 'more'),
#  ('attracting', 'more', 'organic'),
#  ('more', 'organic', 'traffic.'),
#  ('organic', 'traffic.', 'When'),
#  ('traffic.', 'When', 'people'),
#  ('When', 'people', 'search'),
#  ('people', 'search', 'for'),
#  ('search', 'for', 'news-related'),
#  ('for', 'news-related', 'terms,'),
#  ('news-related', 'terms,', 'your'),
#  ('terms,', 'your', 'website'),
#  ('your', 'website', 'will'),
#  ('website', 'will', 'be'),
#  ('will', 'be', 'more'),
#  ('be', 'more', 'likely'),
#  ('more', 'likely', 'to'),
#  ('likely', 'to', 'appear'),
#  ('to', 'appear', 'in'),
#  ('appear', 'in', 'the'),
#  ('in', 'the', 'results'),
#  ('the', 'results', 'due'),
#  ('results', 'due', 'to'),
#  ('due', 'to', 'its'),
#  ('to', 'its', 'relevant'),
#  ('its', 'relevant', 'and'),
#  ('relevant', 'and', 'memorable'),
#  ('and', 'memorable', 'domain'),
#  ('memorable', 'domain', 'name.'),
#  ('domain', 'name.', 'A'),
#  ('name.', 'A', 'domain'),
#  ('A', 'domain', 'like'),
#  ('domain', 'like', 'NewsHelm.com'),
#  ('like', 'NewsHelm.com', 'can'),
#  ('NewsHelm.com', 'can', 'contribute'),
#  ('can', 'contribute', 'to'),
#  ('contribute', 'to', 'the'),
#  ('to', 'the', 'establishment'),
#  ('the', 'establishment', 'of'),
#  ('establishment', 'of', 'a'),
#  ('of', 'a', 'strong'),
#  ('a', 'strong', 'brand'),
#  ('strong', 'brand', 'identity.'),
#  ('brand', 'identity.', 'By'),
#  ('identity.', 'By', 'using'),
#  ('By', 'using', 'a'),
#  ('using', 'a', 'domain'),
#  ('a', 'domain', 'name'),
#  ('domain', 'name', 'that'),
#  ('name', 'that', 'resonates'),
#  ('that', 'resonates', 'with'),
#  ('resonates', 'with', 'your'),
#  ('with', 'your', 'industry'),
#  ('your', 'industry', 'and'),
#  ('industry', 'and', 'audience,'),
#  ('and', 'audience,', "you'll"),
#  ('audience,', "you'll", 'create'),
#  ("you'll", 'create', 'a'),
#  ('create', 'a', 'sense'),
#  ('a', 'sense', 'of'),
#  ('sense', 'of', 'trust'),
#  ('of', 'trust', 'and'),
#  ('trust', 'and', 'reliability.'),
#  ('and', 'reliability.', 'This'),
#  ('reliability.', 'This', 'can'),
#  ('This', 'can', 'help'),
#  ('can', 'help', 'you'),
#  ('help', 'you', 'build'),
#  ('you', 'build', 'customer'),
#  ('build', 'customer', 'loyalty'),
#  ('customer', 'loyalty', 'and'),
#  ('loyalty', 'and', 'attract'),
#  ('and', 'attract', 'new'),
#  ('attract', 'new', 'potential'),
#  ('new', 'potential', 'customers,'),
#  ('potential', 'customers,', 'ultimately'),
#  ('customers,', 'ultimately', 'leading'),
#  ('ultimately', 'leading', 'to'),
#  ('leading', 'to', 'increased'),
#  ('to', 'increased', 'sales'),
#  ('increased', 'sales', 'and'),
#  ('sales', 'and', 'revenue.'),
#  ('and', 'revenue.', 'Buy'),
#  ('revenue.', 'Buy', 'NewsHelm.com'),
#  ('Buy', 'NewsHelm.com', 'Now!'),
#  ('NewsHelm.com', 'Now!', 'At'),
#  ('Now!', 'At', 'DomainMarket.com'),
#  ('At', 'DomainMarket.com', 'our'),
#  ('DomainMarket.com', 'our', 'goal'),
#  ('our', 'goal', 'is'),
#  ('goal', 'is', 'to'),
#  ('is', 'to', 'make'),
#  ('to', 'make', 'the'),
#  ('make', 'the', 'domain'),
#  ('the', 'domain', 'process'),
#  ('domain', 'process', 'as'),
#  ('process', 'as', 'painless'),
#  ('as', 'painless', 'and'),
#  ('painless', 'and', 'transparent'),
#  ('and', 'transparent', 'as'),
#  ('transparent', 'as', 'possible'),
#  ('as', 'possible', 'for'),
#  ('possible', 'for', 'you.'),
#  ('for', 'you.', 'Once'),
#  ('you.', 'Once', 'your'),
#  ('Once', 'your', 'funds'),
#  ('your', 'funds', 'settle'),
#  ('funds', 'settle', 'and'),
#  ('settle', 'and', 'we'),
#  ('and', 'we', 'have'),
#  ('we', 'have', 'verified'),
#  ('have', 'verified', 'the'),
#  ('verified', 'the', 'transaction'),
#  ('the', 'transaction', '(typically'),
#  ('transaction', '(typically', 'between'),
#  ('(typically', 'between', '3'),
#  ('between', '3', 'to'),
#  ('3', 'to', '7'),
#  ('to', '7', 'business'),
#  ('7', 'business', 'days),'),
#  ('business', 'days),', 'we'),
#  ('days),', 'we', 'will'),
#  ('we', 'will', 'be'),
#  ('will', 'be', 'contacting'),
#  ('be', 'contacting', 'you'),
#  ('contacting', 'you', 'via'),
#  ('you', 'via', 'email'),
#  ('via', 'email', 'with'),
#  ('email', 'with', 'the'),
#  ('with', 'the', 'transfer'),
#  ('the', 'transfer', 'instructions'),
#  ('transfer', 'instructions', 'to'),
#  ('instructions', 'to', 'take'),
#  ('to', 'take', 'control'),
#  ('take', 'control', 'of'),
#  ('control', 'of', 'NewsHelm.com.'),
#  ('of', 'NewsHelm.com.', 'To'),
#  ('NewsHelm.com.', 'To', 'acquire'),
#  ('To', 'acquire', 'the'),
#  ('acquire', 'the', 'domain,'),
#  ('the', 'domain,', 'you'),
#  ('domain,', 'you', 'incur'),
#  ('you', 'incur', 'a'),
#  ('incur', 'a', 'one-time'),
#  ('a', 'one-time', 'expense.'),
#  ('one-time', 'expense.', 'Subsequently,'),
#  ('expense.', 'Subsequently,', 'upon'),
#  ('Subsequently,', 'upon', 'the'),
#  ('upon', 'the', 'domain’s'),
#  ('the', 'domain’s', 'transfer'),
#  ('domain’s', 'transfer', 'to'),
#  ('transfer', 'to', 'your'),
#  ('to', 'your', 'ownership,'),
#  ('your', 'ownership,', 'you'),
#  ('ownership,', 'you', 'must'),
#  ('you', 'must', 'annually'),
#  ('must', 'annually', 'renew'),
#  ('annually', 'renew', 'it'),
#  ('renew', 'it', 'through'),
#  ('it', 'through', 'your'),
#  ('through', 'your', 'domain'),
#  ('your', 'domain', 'registrar.'),
#  ('domain', 'registrar.', 'These'),
#  ('registrar.', 'These', 'renewal'),
#  ('These', 'renewal', 'charges'),
#  ('renewal', 'charges', 'varies'),
#  ('charges', 'varies', 'depending'),
#  ('varies', 'depending', 'to'),
#  ('depending', 'to', 'your'),
#  ('to', 'your', 'registrar'),
#  ('your', 'registrar', 'and'),
#  ('registrar', 'and', 'remitted'),
#  ('and', 'remitted', 'directly'),
#  ('remitted', 'directly', 'to'),
#  ('directly', 'to', 'the'),
#  ('to', 'the', 'registrar.'),
#  ('the', 'registrar.', 'We'),
#  ('registrar.', 'We', 'accept'),
#  ('We', 'accept', 'various'),
#  ('accept', 'various', 'payment'),
#  ('various', 'payment', 'methods,'),
#  ('payment', 'methods,', 'including'),
#  ('methods,', 'including', 'major'),
#  ('including', 'major', 'credit'),
#  ('major', 'credit', 'cards,'),
#  ('credit', 'cards,', 'PayPal,'),
#  ('cards,', 'PayPal,', 'and'),
#  ('PayPal,', 'and', 'wire'),
#  ('and', 'wire', 'transfers.'),
#  ('wire', 'transfers.', 'Our'),
#  ('transfers.', 'Our', 'payment'),
#  ('Our', 'payment', 'processing'),
#  ('payment', 'processing', 'system'),
#  ('processing', 'system', 'ensures'),
#  ('system', 'ensures', 'a'),
#  ('ensures', 'a', 'secure'),
#  ('a', 'secure', 'and'),
#  ('secure', 'and', 'hassle-free'),
#  ('and', 'hassle-free', 'transaction'),
#  ('hassle-free', 'transaction', 'experience.')]

# %%
import time

all_unigrams = []
all_bigrams = []
all_trigrams = []


for paragraph in dataset:
  all_unigrams.extend(generate_ngrams(paragraph, 1))
  all_bigrams.extend(generate_ngrams(paragraph, 2))
  all_trigrams.extend(generate_ngrams(paragraph, 3))

  if len(all_unigrams) > 10000:
    time.sleep(1)

# %%
bigram_counts = Counter(all_bigrams)

print("Most common bigrams:")
for bigram, count in bigram_counts.most_common(10):
    print(f"  ({bigram}, {count})")

trigram_counts = Counter(all_trigrams)

print("\n\nMost common trigrams:")
for trigram, count in trigram_counts.most_common(10):
    print(f"  ({trigram}, {count})")
# Out:
# Most common bigrams:
#   (('of', 'the'), 3510)
#   (('in', 'the'), 1763)
#   (('to', 'the'), 1148)
#   (('that', 'the'), 917)
#   (('for', 'the'), 725)
#   (('on', 'the'), 706)
#   (('by', 'the'), 654)
#   (('at', 'the'), 542)
#   (('with', 'the'), 534)
#   (('and', 'the'), 529)
#
#
# Most common trigrams:
#   (('Comments', 'expressed', 'here'), 292)
#   (('expressed', 'here', 'do'), 292)
#   (('here', 'do', 'not'), 292)
#   (('do', 'not', 'reflect'), 292)
#   (('not', 'reflect', 'the'), 292)
#   (('reflect', 'the', 'opinions'), 292)
#   (('the', 'opinions', 'of'), 292)
#   (('opinions', 'of', 'Vanguard'), 292)
#   (('of', 'Vanguard', 'newspapers'), 292)
#   (('Vanguard', 'newspapers', 'or'), 292)

# %%
def generate_ngram_counts(dataset: List[str], n: int) -> Dict[str, Counter]:
  """Generates n-gram counts for the Naijaweb dataset"""

  ngram_counts = defaultdict(Counter)

  for paragraph in dataset:

      ngrams_list = generate_ngrams(paragraph, n)

      for ngram in ngrams_list:
          context = " ".join(ngram[:-1])
          ngram_counts[context][ngram[-1]] += 1

  return dict(ngram_counts)

# %%
sample_dataset = dataset[:2]

generate_ngram_counts(sample_dataset, 3)
# Out:
# {'Governor Samuel': Counter({'Ortom': 2}),
#  'Samuel Ortom': Counter({'of': 2}),
#  'Ortom of': Counter({'Benue': 2}),
#  'of Benue': Counter({'State': 1, 'state': 1}),
#  'Benue State': Counter({'By': 1}),
#  'State By': Counter({'Peter': 1}),
#  'By Peter': Counter({'Duru': 1}),
#  'Peter Duru': Counter({'Governor': 1}),
#  'Duru Governor': Counter({'Samuel': 1}),
#  'Benue state': Counter({'has': 1}),
#  'state has': Counter({'commended': 1}),
#  'has commended': Counter({'President': 1}),
#  'commended President': Counter({'Muhammadu': 1}),
#  'President Muhammadu': Counter({'Buhari': 1}),
#  'Muhammadu Buhari': Counter({'for': 1}),
#  'Buhari for': Counter({'his': 1}),
#  'for his': Counter({'directive': 1, 'recent': 1}),
#  'his directive': Counter({'to': 1}),
#  'directive to': Counter({'security': 1}),
#  'to security': Counter({'agents': 1}),
#  'security agents': Counter({'to': 1}),
#  'agents to': Counter({'shoot': 1}),
#  'to shoot': Counter({'anyone': 1}),
#  'shoot anyone': Counter({'illegally': 1}),
#  'anyone illegally': Counter({'bearing': 1}),
#  'illegally bearing': Counter({'AK47': 1}),
#  'bearing AK47': Counter({'rifle': 1, 'rifles.': 1}),
#  'AK47 rifle': Counter({'in': 1}),
#  'rifle in': Counter({'the': 1}),
#  'in the': Counter({'country.': 1, 'news': 1, 'results': 1}),
#  'the country.': Counter({'The': 1, 'According': 1, 'Comments': 1}),
#  'country. The': Counter({'Governor': 1}),
#  'The Governor': Counter({'who': 1}),
#  'Governor who': Counter({'gave': 1}),
#  'who gave': Counter({'the': 1}),
#  'gave the': Counter({'commendation': 1}),
#  'the commendation': Counter({'Thursday': 1}),
#  'commendation Thursday': Counter({'in': 1}),
#  'Thursday in': Counter({'Makurdi': 1}),
#  'in Makurdi': Counter({'said': 1}),
#  'Makurdi said': Counter({'the': 1}),
#  'said the': Counter({'President’s': 1}),
#  'the President’s': Counter({'order': 1}),
#  'President’s order': Counter({'would': 1}),
#  'order would': Counter({'reduce': 1, 'also': 1}),
#  'would reduce': Counter({'the': 1}),
#  'reduce the': Counter({'level': 1, 'high': 1}),
#  'the level': Counter({'of': 1}),
#  'level of': Counter({'criminality,': 1}),
#  'of criminality,': Counter({'banditry': 1, 'banditary': 1}),
#  'criminality, banditry': Counter({'and': 1}),
#  'banditry and': Counter({'militia': 1}),
#  'and militia': Counter({'herders’': 1, 'herdsmen': 1}),
#  'militia herders’': Counter({'attacks': 1}),
#  'herders’ attacks': Counter({'on': 1}),
#  'attacks on': Counter({'Benue': 1, 'our': 1}),
#  'on Benue': Counter({'communities': 1}),
#  'Benue communities': Counter({'as': 1}),
#  'communities as': Counter({'well': 1}),
#  'as well': Counter({'as': 1}),
#  'well as': Counter({'in': 1}),
#  'as in': Counter({'other': 1}),
#  'in other': Counter({'parts': 1}),
#  'other parts': Counter({'of': 1}),
#  'parts of': Counter({'the': 1}),
#  'of the': Counter({'country.': 2}),
#  'country. According': Counter({'to': 1}),
#  'According to': Counter({'him,': 1}),
#  'to him,': Counter({'“the': 1}),
#  'him, “the': Counter({'order': 1}),
#  '“the order': Counter({'would': 1}),
#  'would also': Counter({'make': 1}),
#  'also make': Counter({'the': 1}),
#  'make the': Counter({'communities': 1, 'domain': 1}),
#  'the communities': Counter({'safer': 1}),
#  'communities safer': Counter({'for': 1}),
#  'safer for': Counter({'displaced': 1}),
#  'for displaced': Counter({'farmers': 1}),
#  'displaced farmers': Counter({'to': 1}),
#  'farmers to': Counter({'return': 1}),
#  'to return': Counter({'to': 1}),
#  'return to': Counter({'their': 1}),
#  'to their': Counter({'ancestral': 1}),
#  'their ancestral': Counter({'homes.': 1}),
#  'ancestral homes.': Counter({'“I': 1}),
#  'homes. “I': Counter({'wish': 1}),
#  '“I wish': Counter({'to': 1}),
#  'wish to': Counter({'commend': 1}),
#  'to commend': Counter({'Mr.': 1}),
#  'commend Mr.': Counter({'President': 1}),
#  'Mr. President': Counter({'for': 1, 'because': 1}),
#  'President for': Counter({'his': 1}),
#  'his recent': Counter({'order': 1}),
#  'recent order': Counter({'against': 1}),
#  'order against': Counter({'those': 1}),
#  'against those': Counter({'bearing': 1}),
#  'those bearing': Counter({'AK47': 1}),
#  'AK47 rifles.': Counter({'This': 1}),
#  'rifles. This': Counter({'I': 1}),
#  'This I': Counter({'am': 1}),
#  'I am': Counter({'sure': 1}),
#  'am sure': Counter({'will': 1}),
#  'sure will': Counter({'reduce': 1}),
#  'will reduce': Counter({'the': 1}),
#  'the high': Counter({'rate': 1}),
#  'high rate': Counter({'of': 1}),
#  'rate of': Counter({'criminality,': 1}),
#  'criminality, banditary': Counter({'and': 1}),
#  'banditary and': Counter({'militia': 1}),
#  'militia herdsmen': Counter({'attacks': 1}),
#  'herdsmen attacks': Counter({'on': 1}),
#  'on our': Counter({'farming': 1}),
#  'our farming': Counter({'communities,”': 1}),
#  'farming communities,”': Counter({'the': 1}),
#  'communities,” the': Counter({'Governor': 1}),
#  'the Governor': Counter({'said.': 1}),
#  'Governor said.': Counter({'He': 1}),
#  'said. He': Counter({'noted': 1}),
#  'He noted': Counter({'that': 1}),
#  'noted that': Counter({'President': 1}),
#  'that President': Counter({'Buhari': 1}),
#  'President Buhari': Counter({'had': 1}),
#  'Buhari had': Counter({'done': 1}),
#  'had done': Counter({'the': 1}),
#  'done the': Counter({'right': 1}),
#  'the right': Counter({'thing': 1}),
#  'right thing': Counter({'by': 1}),
#  'thing by': Counter({'listening': 1}),
#  'by listening': Counter({'to': 1}),
#  'listening to': Counter({'the': 1}),
#  'to the': Counter({'calls': 1, 'establishment': 1, 'registrar.': 1}),
#  'the calls': Counter({'he': 1}),
#  'calls he': Counter({'and': 1}),
#  'he and': Counter({'other': 1}),
#  'and other': Counter({'concerned': 1}),
#  'other concerned': Counter({'Nigerians': 1}),
#  'concerned Nigerians': Counter({'made': 1}),
#  'Nigerians made': Counter({'on': 1}),
#  'made on': Counter({'the': 1}),
#  'on the': Counter({'need': 1, 'rule': 1}),
#  'the need': Counter({'for': 1}),
#  'need for': Counter({'the': 1}),
#  'for the': Counter({'Federal': 1}),
#  'the Federal': Counter({'Government': 1}),
#  'Federal Government': Counter({'to': 1}),
#  'Government to': Counter({'act': 1}),
#  'to act': Counter({'faster': 1}),
#  'act faster': Counter({'and': 1}),
#  'faster and': Counter({'decisively': 1}),
#  'and decisively': Counter({'to': 1}),
#  'decisively to': Counter({'save': 1}),
#  'to save': Counter({'the': 1}),
#  'save the': Counter({'country': 1}),
#  'the country': Counter({'from': 1}),
#  'country from': Counter({'degenerating': 1}),
#  'from degenerating': Counter({'to': 1}),
#  'degenerating to': Counter({'a': 1}),
#  'to a': Counter({'state': 1}),
#  'a state': Counter({'of': 1}),
#  'state of': Counter({'anarchy.': 1}),
#  'of anarchy.': Counter({'“I': 1}),
#  'anarchy. “I': Counter({'don’t': 1}),
#  '“I don’t': Counter({'only': 1}),
#  'don’t only': Counter({'criticise,': 1}),
#  'only criticise,': Counter({'I': 1}),
#  'criticise, I': Counter({'also': 1}),
#  'I also': Counter({'commend': 1}),
#  'also commend': Counter({'where': 1}),
#  'commend where': Counter({'necessary.': 1}),
#  'where necessary.': Counter({'And': 1}),
#  'necessary. And': Counter({'I': 1}),
#  'And I': Counter({'want': 1}),
#  'I want': Counter({'to': 1}),
#  'want to': Counter({'say': 1}),
#  'to say': Counter({'shame': 1}),
#  'say shame': Counter({'on': 1}),
#  'shame on': Counter({'those': 1}),
#  'on those': Counter({'sycophants': 1}),
#  'those sycophants': Counter({'who': 1}),
#  'sycophants who': Counter({'were': 1}),
#  'who were': Counter({'bashing': 1}),
#  'were bashing': Counter({'me': 1}),
#  'bashing me': Counter({'for': 1}),
#  'me for': Counter({'writing': 1}),
#  'for writing': Counter({'to': 1}),
#  'writing to': Counter({'Mr.': 1}),
#  'to Mr.': Counter({'President': 1}),
#  'President because': Counter({'he': 1}),
#  'because he': Counter({'has': 1}),
#  'he has': Counter({'finally': 1}),
#  'has finally': Counter({'heeded': 1}),
#  'finally heeded': Counter({'my': 1}),
#  'heeded my': Counter({'advice,”': 1}),
#  'my advice,”': Counter({'he': 1}),
#  'advice,” he': Counter({'added.': 1}),
#  'he added.': Counter({'Governor': 1}),
#  'added. Governor': Counter({'Ortom': 1}),
#  'Governor Ortom': Counter({'said': 1}),
#  'Ortom said': Counter({'Nigeria': 1}),
#  'said Nigeria': Counter({'belonged': 1}),
#  'Nigeria belonged': Counter({'to': 1}),
#  'belonged to': Counter({'all': 1}),
#  'to all': Counter({'its': 1}),
#  'all its': Counter({'citizens': 1}),
#  'its citizens': Counter({'and': 1}),
#  'citizens and': Counter({'only': 1}),
#  'and only': Counter({'justice': 1}),
#  'only justice': Counter({'and': 1}),
#  'justice and': Counter({'equity': 1}),
#  'and equity': Counter({'anchored': 1}),
#  'equity anchored': Counter({'on': 1}),
#  'anchored on': Counter({'the': 1}),
#  'the rule': Counter({'of': 1}),
#  'rule of': Counter({'law': 1}),
#  'of law': Counter({'could': 1}),
#  'law could': Counter({'guarantee': 1}),
#  'could guarantee': Counter({'the': 1}),
#  'guarantee the': Counter({'unity': 1}),
#  'the unity': Counter({'and': 1}),
#  'unity and': Counter({'stability': 1}),
#  'and stability': Counter({'of': 1}),
#  'stability of': Counter({'the': 1}),
#  'country. Comments': Counter({'expressed': 1}),
#  'Comments expressed': Counter({'here': 1}),
#  'expressed here': Counter({'do': 1}),
#  'here do': Counter({'not': 1}),
#  'do not': Counter({'reflect': 1}),
#  'not reflect': Counter({'the': 1}),
#  'reflect the': Counter({'opinions': 1}),
#  'the opinions': Counter({'of': 1}),
#  'opinions of': Counter({'Vanguard': 1}),
#  'of Vanguard': Counter({'newspapers': 1}),
#  'Vanguard newspapers': Counter({'or': 1}),
#  'newspapers or': Counter({'any': 1}),
#  'or any': Counter({'employee': 1}),
#  'any employee': Counter({'thereof.': 1}),
#  'NewsHelm.com offers': Counter({'a': 1}),
#  'offers a': Counter({'unique': 1}),
#  'a unique': Counter({'blend': 1}),
#  'unique blend': Counter({'of': 1}),
#  'blend of': Counter({'modernity': 1}),
#  'of modernity': Counter({'and': 1}),
#  'modernity and': Counter({'trustworthiness.': 1}),
#  'and trustworthiness.': Counter({'Its': 1}),
#  'trustworthiness. Its': Counter({'short': 1}),
#  'Its short': Counter({'and': 1}),
#  'short and': Counter({'catchy': 1}),
#  'and catchy': Counter({'name': 1}),
#  'catchy name': Counter({'instantly': 1}),
#  'name instantly': Counter({'conveys': 1}),
#  'instantly conveys': Counter({'the': 1}),
#  'conveys the': Counter({'idea': 1}),
#  'the idea': Counter({'of': 1}),
#  'idea of': Counter({'a': 1}),
#  'of a': Counter({'news': 1, 'strong': 1}),
#  'a news': Counter({'or': 1}),
#  'news or': Counter({'media': 1}),
#  'or media': Counter({'platform.': 1}),
#  'media platform.': Counter({'This': 1}),
#  'platform. This': Counter({'domain': 1}),
#  'This domain': Counter({'name': 1}),
#  'domain name': Counter({'is': 1, 'that': 1}),
#  'name is': Counter({'ideal': 1}),
#  'is ideal': Counter({'for': 1}),
#  'ideal for': Counter({'businesses': 1}),
#  'for businesses': Counter({'in': 1}),
#  'businesses in': Counter({'the': 1}),
#  'the news': Counter({'industry,': 1}),
#  'news industry,': Counter({'such': 1}),
#  'industry, such': Counter({'as': 1}),
#  'such as': Counter({'broadcasting,': 1}),
#  'as broadcasting,': Counter({'publishing,': 1}),
#  'broadcasting, publishing,': Counter({'or': 1}),
#  'publishing, or': Counter({'journalism.': 1}),
#  'or journalism.': Counter({'With': 1}),
#  'journalism. With': Counter({'NewsHelm.com,': 1}),
#  'With NewsHelm.com,': Counter({"you'll": 1}),
#  "NewsHelm.com, you'll": Counter({'establish': 1}),
#  "you'll establish": Counter({'a': 1}),
#  'establish a': Counter({'strong': 1}),
#  'a strong': Counter({'online': 1, 'brand': 1}),
#  'strong online': Counter({'presence': 1}),
#  'online presence': Counter({'and': 1}),
#  'presence and': Counter({'build': 1}),
#  'and build': Counter({'trust': 1}),
#  'build trust': Counter({'with': 1}),
#  'trust with': Counter({'your': 1}),
#  'with your': Counter({'audience.': 1, 'industry': 1}),
#  'your audience.': Counter({"NewsHelm.com's": 1}),
#  "audience. NewsHelm.com's": Counter({'marketability': 1}),
#  "NewsHelm.com's marketability": Counter({'extends': 1}),
#  'marketability extends': Counter({'beyond': 1}),
#  'extends beyond': Counter({'the': 1}),
#  'beyond the': Counter({'digital': 1}),
#  'the digital': Counter({'realm.': 1}),
#  'digital realm.': Counter({'It': 1}),
#  'realm. It': Counter({'can': 1}),
#  'It can': Counter({'also': 1, 'improve': 1}),
#  'can also': Counter({'be': 1}),
#  'also be': Counter({'used': 1}),
#  'be used': Counter({'for': 1}),
#  'used for': Counter({'branding': 1}),
#  'for branding': Counter({'offline': 1}),
#  'branding offline': Counter({'materials': 1}),
#  'offline materials': Counter({'like': 1}),
#  'materials like': Counter({'business': 1}),
#  'like business': Counter({'cards,': 1}),
#  'business cards,': Counter({'brochures,': 1}),
#  'cards, brochures,': Counter({'or': 1}),
#  'brochures, or': Counter({'signage.': 1}),
#  'or signage.': Counter({'Additionally,': 1}),
#  'signage. Additionally,': Counter({'its': 1}),
#  'Additionally, its': Counter({'easy-to-remember': 1}),
#  'its easy-to-remember': Counter({'nature': 1}),
#  'easy-to-remember nature': Counter({'makes': 1}),
#  'nature makes': Counter({'it': 1}),
#  'makes it': Counter({'perfect': 1}),
#  'it perfect': Counter({'for': 1}),
#  'perfect for': Counter({'radio': 1}),
#  'for radio': Counter({'or': 1}),
#  'radio or': Counter({'television': 1}),
#  'or television': Counter({'ads,': 1}),
#  'television ads,': Counter({'ensuring': 1}),
#  'ads, ensuring': Counter({'that': 1}),
#  'ensuring that': Counter({'your': 1}),
#  'that your': Counter({'brand': 1}),
#  'your brand': Counter({'sticks': 1}),
#  'brand sticks': Counter({'in': 1}),
#  'sticks in': Counter({"listeners'": 1}),
#  "in listeners'": Counter({'or': 1}),
#  "listeners' or": Counter({"viewers'": 1}),
#  "or viewers'": Counter({'minds.': 1}),
#  "viewers' minds.": Counter({'NewsHelm.com': 1}),
#  'minds. NewsHelm.com': Counter({'can': 1}),
#  'NewsHelm.com can': Counter({'significantly': 1, 'contribute': 1}),
#  'can significantly': Counter({'enhance': 1}),
#  'significantly enhance': Counter({'your': 1}),
#  'enhance your': Counter({'online': 1}),
#  'your online': Counter({'visibility': 1}),
#  'online visibility': Counter({'and': 1}),
#  'visibility and': Counter({'reach.': 1}),
#  'and reach.': Counter({'It': 1}),
#  'reach. It': Counter({'can': 1}),
#  'can improve': Counter({'your': 1}),
#  'improve your': Counter({'search': 1}),
#  'your search': Counter({'engine': 1}),
#  'search engine': Counter({'rankings': 1}),
#  'engine rankings': Counter({'by': 1}),
#  'rankings by': Counter({'attracting': 1}),
#  'by attracting': Counter({'more': 1}),
#  'attracting more': Counter({'organic': 1}),
#  'more organic': Counter({'traffic.': 1}),
#  'organic traffic.': Counter({'When': 1}),
#  'traffic. When': Counter({'people': 1}),
#  'When people': Counter({'search': 1}),
#  'people search': Counter({'for': 1}),
#  'search for': Counter({'news-related': 1}),
#  'for news-related': Counter({'terms,': 1}),
#  'news-related terms,': Counter({'your': 1}),
#  'terms, your': Counter({'website': 1}),
#  'your website': Counter({'will': 1}),
#  'website will': Counter({'be': 1}),
#  'will be': Counter({'more': 1, 'contacting': 1}),
#  'be more': Counter({'likely': 1}),
#  'more likely': Counter({'to': 1}),
#  'likely to': Counter({'appear': 1}),
#  'to appear': Counter({'in': 1}),
#  'appear in': Counter({'the': 1}),
#  'the results': Counter({'due': 1}),
#  'results due': Counter({'to': 1}),
#  'due to': Counter({'its': 1}),
#  'to its': Counter({'relevant': 1}),
#  'its relevant': Counter({'and': 1}),
#  'relevant and': Counter({'memorable': 1}),
#  'and memorable': Counter({'domain': 1}),
#  'memorable domain': Counter({'name.': 1}),
#  'domain name.': Counter({'A': 1}),
#  'name. A': Counter({'domain': 1}),
#  'A domain': Counter({'like': 1}),
#  'domain like': Counter({'NewsHelm.com': 1}),
#  'like NewsHelm.com': Counter({'can': 1}),
#  'can contribute': Counter({'to': 1}),
#  'contribute to': Counter({'the': 1}),
#  'the establishment': Counter({'of': 1}),
#  'establishment of': Counter({'a': 1}),
#  'strong brand': Counter({'identity.': 1}),
#  'brand identity.': Counter({'By': 1}),
#  'identity. By': Counter({'using': 1}),
#  'By using': Counter({'a': 1}),
#  'using a': Counter({'domain': 1}),
#  'a domain': Counter({'name': 1}),
#  'name that': Counter({'resonates': 1}),
#  'that resonates': Counter({'with': 1}),
#  'resonates with': Counter({'your': 1}),
#  'your industry': Counter({'and': 1}),
#  'industry and': Counter({'audience,': 1}),
#  'and audience,': Counter({"you'll": 1}),
#  "audience, you'll": Counter({'create': 1}),
#  "you'll create": Counter({'a': 1}),
#  'create a': Counter({'sense': 1}),
#  'a sense': Counter({'of': 1}),
#  'sense of': Counter({'trust': 1}),
#  'of trust': Counter({'and': 1}),
#  'trust and': Counter({'reliability.': 1}),
#  'and reliability.': Counter({'This': 1}),
#  'reliability. This': Counter({'can': 1}),
#  'This can': Counter({'help': 1}),
#  'can help': Counter({'you': 1}),
#  'help you': Counter({'build': 1}),
#  'you build': Counter({'customer': 1}),
#  'build customer': Counter({'loyalty': 1}),
#  'customer loyalty': Counter({'and': 1}),
#  'loyalty and': Counter({'attract': 1}),
#  'and attract': Counter({'new': 1}),
#  'attract new': Counter({'potential': 1}),
#  'new potential': Counter({'customers,': 1}),
#  'potential customers,': Counter({'ultimately': 1}),
#  'customers, ultimately': Counter({'leading': 1}),
#  'ultimately leading': Counter({'to': 1}),
#  'leading to': Counter({'increased': 1}),
#  'to increased': Counter({'sales': 1}),
#  'increased sales': Counter({'and': 1}),
#  'sales and': Counter({'revenue.': 1}),
#  'and revenue.': Counter({'Buy': 1}),
#  'revenue. Buy': Counter({'NewsHelm.com': 1}),
#  'Buy NewsHelm.com': Counter({'Now!': 1}),
#  'NewsHelm.com Now!': Counter({'At': 1}),
#  'Now! At': Counter({'DomainMarket.com': 1}),
#  'At DomainMarket.com': Counter({'our': 1}),
#  'DomainMarket.com our': Counter({'goal': 1}),
#  'our goal': Counter({'is': 1}),
#  'goal is': Counter({'to': 1}),
#  'is to': Counter({'make': 1}),
#  'to make': Counter({'the': 1}),
#  'the domain': Counter({'process': 1}),
#  'domain process': Counter({'as': 1}),
#  'process as': Counter({'painless': 1}),
#  'as painless': Counter({'and': 1}),
#  'painless and': Counter({'transparent': 1}),
#  'and transparent': Counter({'as': 1}),
#  'transparent as': Counter({'possible': 1}),
#  'as possible': Counter({'for': 1}),
#  'possible for': Counter({'you.': 1}),
#  'for you.': Counter({'Once': 1}),
#  'you. Once': Counter({'your': 1}),
#  'Once your': Counter({'funds': 1}),
#  'your funds': Counter({'settle': 1}),
#  'funds settle': Counter({'and': 1}),
#  'settle and': Counter({'we': 1}),
#  'and we': Counter({'have': 1}),
#  'we have': Counter({'verified': 1}),
#  'have verified': Counter({'the': 1}),
#  'verified the': Counter({'transaction': 1}),
#  'the transaction': Counter({'(typically': 1}),
#  'transaction (typically': Counter({'between': 1}),
#  '(typically between': Counter({'3': 1}),
#  'between 3': Counter({'to': 1}),
#  '3 to': Counter({'7': 1}),
#  'to 7': Counter({'business': 1}),
#  '7 business': Counter({'days),': 1}),
#  'business days),': Counter({'we': 1}),
#  'days), we': Counter({'will': 1}),
#  'we will': Counter({'be': 1}),
#  'be contacting': Counter({'you': 1}),
#  'contacting you': Counter({'via': 1}),
#  'you via': Counter({'email': 1}),
#  'via email': Counter({'with': 1}),
#  'email with': Counter({'the': 1}),
#  'with the': Counter({'transfer': 1}),
#  'the transfer': Counter({'instructions': 1}),
#  'transfer instructions': Counter({'to': 1}),
#  'instructions to': Counter({'take': 1}),
#  'to take': Counter({'control': 1}),
#  'take control': Counter({'of': 1}),
#  'control of': Counter({'NewsHelm.com.': 1}),
#  'of NewsHelm.com.': Counter({'To': 1}),
#  'NewsHelm.com. To': Counter({'acquire': 1}),
#  'To acquire': Counter({'the': 1}),
#  'acquire the': Counter({'domain,': 1}),
#  'the domain,': Counter({'you': 1}),
#  'domain, you': Counter({'incur': 1}),
#  'you incur': Counter({'a': 1}),
#  'incur a': Counter({'one-time': 1}),
#  'a one-time': Counter({'expense.': 1}),
#  'one-time expense.': Counter({'Subsequently,': 1}),
#  'expense. Subsequently,': Counter({'upon': 1}),
#  'Subsequently, upon': Counter({'the': 1}),
#  'upon the': Counter({'domain’s': 1}),
#  'the domain’s': Counter({'transfer': 1}),
#  'domain’s transfer': Counter({'to': 1}),
#  'transfer to': Counter({'your': 1}),
#  'to your': Counter({'ownership,': 1, 'registrar': 1}),
#  'your ownership,': Counter({'you': 1}),
#  'ownership, you': Counter({'must': 1}),
#  'you must': Counter({'annually': 1}),
#  'must annually': Counter({'renew': 1}),
#  'annually renew': Counter({'it': 1}),
#  'renew it': Counter({'through': 1}),
#  'it through': Counter({'your': 1}),
#  'through your': Counter({'domain': 1}),
#  'your domain': Counter({'registrar.': 1}),
#  'domain registrar.': Counter({'These': 1}),
#  'registrar. These': Counter({'renewal': 1}),
#  'These renewal': Counter({'charges': 1}),
#  'renewal charges': Counter({'varies': 1}),
#  'charges varies': Counter({'depending': 1}),
#  'varies depending': Counter({'to': 1}),
#  'depending to': Counter({'your': 1}),
#  'your registrar': Counter({'and': 1}),
#  'registrar and': Counter({'remitted': 1}),
#  'and remitted': Counter({'directly': 1}),
#  'remitted directly': Counter({'to': 1}),
#  'directly to': Counter({'the': 1}),
#  'the registrar.': Counter({'We': 1}),
#  'registrar. We': Counter({'accept': 1}),
#  'We accept': Counter({'various': 1}),
#  'accept various': Counter({'payment': 1}),
#  'various payment': Counter({'methods,': 1}),
#  'payment methods,': Counter({'including': 1}),
#  'methods, including': Counter({'major': 1}),
#  'including major': Counter({'credit': 1}),
#  'major credit': Counter({'cards,': 1}),
#  'credit cards,': Counter({'PayPal,': 1}),
#  'cards, PayPal,': Counter({'and': 1}),
#  'PayPal, and': Counter({'wire': 1}),
#  'and wire': Counter({'transfers.': 1}),
#  'wire transfers.': Counter({'Our': 1}),
#  'transfers. Our': Counter({'payment': 1}),
#  'Our payment': Counter({'processing': 1}),
#  'payment processing': Counter({'system': 1}),
#  'processing system': Counter({'ensures': 1}),
#  'system ensures': Counter({'a': 1}),
#  'ensures a': Counter({'secure': 1}),
#  'a secure': Counter({'and': 1}),
#  'secure and': Counter({'hassle-free': 1}),
#  'and hassle-free': Counter({'transaction': 1}),
#  'hassle-free transaction': Counter({'experience.': 1})}

# %%
def build_ngram_model(
    dataset: List[str],
    n: int
) -> Dict[str, Dict[str, float]]:
    """Build an n-gram language model."""

    ngram_model = defaultdict(dict)

    ngram_counts = generate_ngram_counts(dataset, n)

    for context, next_tokens in ngram_counts.items():
        total = sum(next_tokens.values())
        for next_token, counts in next_tokens.items():
          ngram_model[context][next_token] = counts/total

    return ngram_model

# Testing the function
test_dataset = ["The governor is tall.", "The governor is greedy."]
test_trigram_model = build_ngram_model(test_dataset, n=3)
test_trigram_model
# Out:
# {'The governor': {'is': 1.0}, 'governor is': {'tall.': 0.5, 'greedy.': 0.5}}

# %%
def generate_output(
    prompt: str,
    n: int,
    num_of_tokens: int,
    ngram_model: Dict[str, Dict[str, float]]
) -> str:
    """Generates new token output for ngram model"""

    generated_tokens = space_tokenizer(prompt)

    for _ in range(num_of_tokens):
        context = generated_tokens[-(n - 1):]
        context = " ".join(context)
        if context in ngram_model:
            next_word = random.choices(
                list(ngram_model[context].keys()),
                weights=ngram_model[context].values()
            )[0]

            generated_tokens.append(next_word)
        else:
            print("No valid continuation found")
            break

    return " ".join(generated_tokens)

# %% [markdown]
# ## Inference with new n-gram model

# %%
prompt = "he lamented"

trigram_model = build_ngram_model(dataset, n=3)

output = generate_output(prompt, n=3, num_of_tokens=20, ngram_model=trigram_model)

print(output)
# Out:
# he lamented as the refusal of Imo State. With the sum of $75 million because the parents and relatives, colleagues and generals

# %% [markdown]
# ## References
#
# Dataset Used
#
# [1] Saheed Azeez. (2024). *Naijaweb: A Web Scraped Nigerian Context Dataset* (Version 1.0.0). Hugging Face Datasets. Available at: [https://huggingface.co/datasets/saheedniyi/naijaweb](https://huggingface.co/datasets/saheedniyi/naijaweb)
